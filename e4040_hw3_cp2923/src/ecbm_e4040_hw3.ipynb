# %% [markdown]
# ### Example for using function load_data and printing dataset

# %%
from hw3_utils import load_data
import theano.tensor as T
import matplotlib.pyplot as plt
#downsample the training and validation dataset if needed, ds_rate should be larger than 1.
ds_rate=None
datasets = load_data(ds_rate=ds_rate,theano_shared=False)
train_set_x, train_set_y = datasets[0]
valid_set_x, valid_set_y = datasets[1]
test_set_x, test_set_y = datasets[2]
print('Current training data size is %i'%train_set_x.shape[0])
print('Current validation data size is %i'%valid_set_x.shape[0])
print('Current test data size is %i'%test_set_x.shape[0])
# Out:
# Current training data size is 40000
# Current validation data size is 10000
# Current test data size is 10000
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
class_=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
#Choose an image index
i=15
plt.imshow(np.reshape(valid_set_x[i],(3,32,32)).transpose(1,2,0))
plt.xticks([])
plt.yticks([])
plt.title('Original picture')
plt.xlabel('%s'%class_[valid_set_y[i]])

# %% [markdown]
# # ECBM E6040 Homework 3 - Programming Problem

# %% [markdown]
# ### Problem 1: Implement the convolutional neural network depicted in this problem

# %%
from hw3 import test_lenet
test_lenet(datasets, learning_rate=0.05, n_epochs=200,nkerns=[32, 64], batch_size=300, activation = T.nnet.relu)
# Out:
# ... building the model
# ... training
# training @ iter = 0
# training @ iter = 100
# epoch 1, minibatch 133/133, validation error 75.252525 %
#      epoch 1, minibatch 133/133, test error of best model 74.404040 %
# training @ iter = 200
# epoch 2, minibatch 133/133, validation error 62.757576 %
#      epoch 2, minibatch 133/133, test error of best model 62.101010 %
# training @ iter = 300
# epoch 3, minibatch 133/133, validation error 58.383838 %
#      epoch 3, minibatch 133/133, test error of best model 57.929293 %
# training @ iter = 400
# training @ iter = 500
# epoch 4, minibatch 133/133, validation error 55.181818 %
#      epoch 4, minibatch 133/133, test error of best model 55.090909 %
# training @ iter = 600
# epoch 5, minibatch 133/133, validation error 52.030303 %
#      epoch 5, minibatch 133/133, test error of best model 52.303030 %
# training @ iter = 700
# epoch 6, minibatch 133/133, validation error 49.202020 %
#      epoch 6, minibatch 133/133, test error of best model 49.363636 %
# training @ iter = 800
# training @ iter = 900
# epoch 7, minibatch 133/133, validation error 46.979798 %
#      epoch 7, minibatch 133/133, test error of best model 47.060606 %
# training @ iter = 1000
# epoch 8, minibatch 133/133, validation error 44.909091 %
#      epoch 8, minibatch 133/133, test error of best model 45.050505 %
# training @ iter = 1100
# epoch 9, minibatch 133/133, validation error 43.494949 %
#      epoch 9, minibatch 133/133, test error of best model 43.242424 %
# training @ iter = 1200
# training @ iter = 1300
# epoch 10, minibatch 133/133, validation error 44.050505 %
# training @ iter = 1400
# epoch 11, minibatch 133/133, validation error 39.434343 %
#      epoch 11, minibatch 133/133, test error of best model 39.434343 %
# training @ iter = 1500
# epoch 12, minibatch 133/133, validation error 38.212121 %
#      epoch 12, minibatch 133/133, test error of best model 37.969697 %
# training @ iter = 1600
# training @ iter = 1700
# epoch 13, minibatch 133/133, validation error 37.585859 %
#      epoch 13, minibatch 133/133, test error of best model 36.909091 %
# training @ iter = 1800
# epoch 14, minibatch 133/133, validation error 37.303030 %
#      epoch 14, minibatch 133/133, test error of best model 36.818182 %
# training @ iter = 1900
# epoch 15, minibatch 133/133, validation error 36.464646 %
#      epoch 15, minibatch 133/133, test error of best model 36.000000 %
# training @ iter = 2000
# training @ iter = 2100
# epoch 16, minibatch 133/133, validation error 36.717172 %
# training @ iter = 2200
# epoch 17, minibatch 133/133, validation error 34.797980 %
#      epoch 17, minibatch 133/133, test error of best model 34.494949 %
# training @ iter = 2300
# epoch 18, minibatch 133/133, validation error 39.252525 %
# training @ iter = 2400
# training @ iter = 2500
# epoch 19, minibatch 133/133, validation error 34.808081 %
# training @ iter = 2600
# epoch 20, minibatch 133/133, validation error 33.383838 %
#      epoch 20, minibatch 133/133, test error of best model 33.282828 %
# training @ iter = 2700
# epoch 21, minibatch 133/133, validation error 36.333333 %
# training @ iter = 2800
# training @ iter = 2900
# epoch 22, minibatch 133/133, validation error 35.555556 %
# training @ iter = 3000
# epoch 23, minibatch 133/133, validation error 34.121212 %
# training @ iter = 3100
# epoch 24, minibatch 133/133, validation error 32.898990 %
#      epoch 24, minibatch 133/133, test error of best model 33.424242 %
# training @ iter = 3200
# training @ iter = 3300
# epoch 25, minibatch 133/133, validation error 32.242424 %
#      epoch 25, minibatch 133/133, test error of best model 32.565657 %
# training @ iter = 3400
# epoch 26, minibatch 133/133, validation error 35.070707 %
# training @ iter = 3500
# epoch 27, minibatch 133/133, validation error 32.676768 %
# training @ iter = 3600
# training @ iter = 3700
# epoch 28, minibatch 133/133, validation error 33.646465 %
# training @ iter = 3800
# epoch 29, minibatch 133/133, validation error 32.747475 %
# training @ iter = 3900
# epoch 30, minibatch 133/133, validation error 32.919192 %
# training @ iter = 4000
# training @ iter = 4100
# epoch 31, minibatch 133/133, validation error 32.191919 %
#      epoch 31, minibatch 133/133, test error of best model 32.363636 %
# training @ iter = 4200
# epoch 32, minibatch 133/133, validation error 31.979798 %
#      epoch 32, minibatch 133/133, test error of best model 32.333333 %
# training @ iter = 4300
# epoch 33, minibatch 133/133, validation error 31.777778 %
#      epoch 33, minibatch 133/133, test error of best model 32.242424 %
# training @ iter = 4400
# training @ iter = 4500
# epoch 34, minibatch 133/133, validation error 31.555556 %
#      epoch 34, minibatch 133/133, test error of best model 31.838384 %
# training @ iter = 4600
# epoch 35, minibatch 133/133, validation error 31.343434 %
#      epoch 35, minibatch 133/133, test error of best model 31.585859 %
# training @ iter = 4700
# epoch 36, minibatch 133/133, validation error 31.303030 %
#      epoch 36, minibatch 133/133, test error of best model 31.515152 %
# training @ iter = 4800
# training @ iter = 4900
# epoch 37, minibatch 133/133, validation error 31.323232 %
# training @ iter = 5000
# epoch 38, minibatch 133/133, validation error 31.202020 %
#      epoch 38, minibatch 133/133, test error of best model 31.434343 %
# training @ iter = 5100
# epoch 39, minibatch 133/133, validation error 31.232323 %
# training @ iter = 5200
# training @ iter = 5300
# epoch 40, minibatch 133/133, validation error 31.101010 %
#      epoch 40, minibatch 133/133, test error of best model 31.242424 %
# training @ iter = 5400
# epoch 41, minibatch 133/133, validation error 31.121212 %
# training @ iter = 5500
# epoch 42, minibatch 133/133, validation error 31.070707 %
#      epoch 42, minibatch 133/133, test error of best model 31.080808 %
# training @ iter = 5600
# training @ iter = 5700
# epoch 43, minibatch 133/133, validation error 31.111111 %
# training @ iter = 5800
# epoch 44, minibatch 133/133, validation error 31.020202 %
#      epoch 44, minibatch 133/133, test error of best model 31.020202 %
# training @ iter = 5900
# epoch 45, minibatch 133/133, validation error 30.989899 %
#      epoch 45, minibatch 133/133, test error of best model 31.020202 %
# training @ iter = 6000
# training @ iter = 6100
# epoch 46, minibatch 133/133, validation error 30.929293 %
#      epoch 46, minibatch 133/133, test error of best model 31.000000 %
# training @ iter = 6200
# epoch 47, minibatch 133/133, validation error 30.939394 %
# training @ iter = 6300
# epoch 48, minibatch 133/133, validation error 31.020202 %
# training @ iter = 6400
# training @ iter = 6500
# epoch 49, minibatch 133/133, validation error 30.939394 %
# training @ iter = 6600
# epoch 50, minibatch 133/133, validation error 30.898990 %
#      epoch 50, minibatch 133/133, test error of best model 31.030303 %
# training @ iter = 6700
# epoch 51, minibatch 133/133, validation error 30.919192 %
# training @ iter = 6800
# training @ iter = 6900
# epoch 52, minibatch 133/133, validation error 30.848485 %
#      epoch 52, minibatch 133/133, test error of best model 31.060606 %
# training @ iter = 7000
# epoch 53, minibatch 133/133, validation error 30.868687 %
# training @ iter = 7100
# epoch 54, minibatch 133/133, validation error 30.868687 %
# training @ iter = 7200
# training @ iter = 7300
# epoch 55, minibatch 133/133, validation error 30.848485 %
# training @ iter = 7400
# epoch 56, minibatch 133/133, validation error 30.848485 %
#      epoch 56, minibatch 133/133, test error of best model 30.989899 %
# training @ iter = 7500
# epoch 57, minibatch 133/133, validation error 30.858586 %
# training @ iter = 7600
# training @ iter = 7700
# epoch 58, minibatch 133/133, validation error 30.818182 %
#      epoch 58, minibatch 133/133, test error of best model 31.020202 %
# training @ iter = 7800
# epoch 59, minibatch 133/133, validation error 30.848485 %
# training @ iter = 7900
# epoch 60, minibatch 133/133, validation error 30.868687 %
# training @ iter = 8000
# training @ iter = 8100
# epoch 61, minibatch 133/133, validation error 30.878788 %
# training @ iter = 8200
# epoch 62, minibatch 133/133, validation error 30.828283 %
# training @ iter = 8300
# epoch 63, minibatch 133/133, validation error 30.818182 %
#      epoch 63, minibatch 133/133, test error of best model 30.949495 %
# training @ iter = 8400
# training @ iter = 8500
# epoch 64, minibatch 133/133, validation error 30.797980 %
#      epoch 64, minibatch 133/133, test error of best model 30.959596 %
# training @ iter = 8600
# epoch 65, minibatch 133/133, validation error 30.797980 %
# training @ iter = 8700
# epoch 66, minibatch 133/133, validation error 30.787879 %
#      epoch 66, minibatch 133/133, test error of best model 30.959596 %
# training @ iter = 8800
# training @ iter = 8900
# epoch 67, minibatch 133/133, validation error 30.777778 %
#      epoch 67, minibatch 133/133, test error of best model 30.909091 %
# training @ iter = 9000
# epoch 68, minibatch 133/133, validation error 30.757576 %
#      epoch 68, minibatch 133/133, test error of best model 30.888889 %
# training @ iter = 9100
# epoch 69, minibatch 133/133, validation error 30.767677 %
# training @ iter = 9200
# training @ iter = 9300
# epoch 70, minibatch 133/133, validation error 30.747475 %
#      epoch 70, minibatch 133/133, test error of best model 30.858586 %
# training @ iter = 9400
# epoch 71, minibatch 133/133, validation error 30.747475 %
#      epoch 71, minibatch 133/133, test error of best model 30.848485 %
# training @ iter = 9500
# epoch 72, minibatch 133/133, validation error 30.757576 %
# training @ iter = 9600
# training @ iter = 9700
# epoch 73, minibatch 133/133, validation error 30.747475 %
# training @ iter = 9800
# epoch 74, minibatch 133/133, validation error 30.747475 %
# training @ iter = 9900
# epoch 75, minibatch 133/133, validation error 30.777778 %
# training @ iter = 10000
# Optimization complete.
# Best validation score of 30.747475 % obtained at iteration 9443, with test performance 30.848485 %
# The code for file hw3.py ran for 30.75m
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %% [markdown]
# ### Problem 2: Bullet 1: Augmentation by translation

# %% [markdown]
# Show a 4*4 figure of 16 input images with this augmentation

# %%
from hw3_utils import load_data
import matplotlib.pyplot as plt
from hw3 import translate_image
# %matplotlib inline
axarr = plt.subplots(4,4)[1]
for i in range(4):
    for j in range(4):
        plt.axes(axarr[i,j])
        translate_image(img = datasets[0][0][i*4+j], left = 2, up = 3, imgplot = True)

# %% [markdown]
# Implement the neural network with this augmentation, show the improvement

# %%
from hw3 import test_lenet_translation
test_lenet_translation(datasets, learning_rate=0.05, n_epochs=200,nkerns=[32, 64], batch_size=300, activation = T.nnet.relu)
# Out:
# ... building the model
# ... training
# training @ iter = 0
# training @ iter = 100
# epoch 1, minibatch 133/133, validation error 74.686869 %
#      epoch 1, minibatch 133/133, test error of best model 73.636364 %
# training @ iter = 200
# epoch 2, minibatch 133/133, validation error 62.777778 %
#      epoch 2, minibatch 133/133, test error of best model 62.282828 %
# training @ iter = 300
# epoch 3, minibatch 133/133, validation error 58.787879 %
#      epoch 3, minibatch 133/133, test error of best model 58.030303 %
# training @ iter = 400
# training @ iter = 500
# epoch 4, minibatch 133/133, validation error 55.646465 %
#      epoch 4, minibatch 133/133, test error of best model 55.737374 %
# training @ iter = 600
# epoch 5, minibatch 133/133, validation error 52.707071 %
#      epoch 5, minibatch 133/133, test error of best model 52.909091 %
# training @ iter = 700
# epoch 6, minibatch 133/133, validation error 49.474747 %
#      epoch 6, minibatch 133/133, test error of best model 49.787879 %
# training @ iter = 800
# training @ iter = 900
# epoch 7, minibatch 133/133, validation error 47.343434 %
#      epoch 7, minibatch 133/133, test error of best model 47.363636 %
# training @ iter = 1000
# epoch 8, minibatch 133/133, validation error 45.080808 %
#      epoch 8, minibatch 133/133, test error of best model 45.191919 %
# training @ iter = 1100
# epoch 9, minibatch 133/133, validation error 42.949495 %
#      epoch 9, minibatch 133/133, test error of best model 42.626263 %
# training @ iter = 1200
# training @ iter = 1300
# epoch 10, minibatch 133/133, validation error 41.000000 %
#      epoch 10, minibatch 133/133, test error of best model 40.868687 %
# training @ iter = 1400
# epoch 11, minibatch 133/133, validation error 39.737374 %
#      epoch 11, minibatch 133/133, test error of best model 39.585859 %
# training @ iter = 1500
# epoch 12, minibatch 133/133, validation error 38.222222 %
#      epoch 12, minibatch 133/133, test error of best model 38.191919 %
# training @ iter = 1600
# training @ iter = 1700
# epoch 13, minibatch 133/133, validation error 37.373737 %
#      epoch 13, minibatch 133/133, test error of best model 37.252525 %
# training @ iter = 1800
# epoch 14, minibatch 133/133, validation error 36.606061 %
#      epoch 14, minibatch 133/133, test error of best model 36.383838 %
# training @ iter = 1900
# epoch 15, minibatch 133/133, validation error 36.313131 %
#      epoch 15, minibatch 133/133, test error of best model 36.262626 %
# training @ iter = 2000
# training @ iter = 2100
# epoch 16, minibatch 133/133, validation error 36.181818 %
#      epoch 16, minibatch 133/133, test error of best model 36.282828 %
# training @ iter = 2200
# epoch 17, minibatch 133/133, validation error 34.494949 %
#      epoch 17, minibatch 133/133, test error of best model 34.676768 %
# training @ iter = 2300
# epoch 18, minibatch 133/133, validation error 36.666667 %
# training @ iter = 2400
# training @ iter = 2500
# epoch 19, minibatch 133/133, validation error 36.858586 %
# training @ iter = 2600
# epoch 20, minibatch 133/133, validation error 35.282828 %
# training @ iter = 2700
# epoch 21, minibatch 133/133, validation error 34.141414 %
#      epoch 21, minibatch 133/133, test error of best model 34.181818 %
# training @ iter = 2800
# training @ iter = 2900
# epoch 22, minibatch 133/133, validation error 34.191919 %
# training @ iter = 3000
# epoch 23, minibatch 133/133, validation error 33.090909 %
#      epoch 23, minibatch 133/133, test error of best model 32.959596 %
# training @ iter = 3100
# epoch 24, minibatch 133/133, validation error 33.111111 %
# training @ iter = 3200
# training @ iter = 3300
# epoch 25, minibatch 133/133, validation error 33.848485 %
# training @ iter = 3400
# epoch 26, minibatch 133/133, validation error 34.050505 %
# training @ iter = 3500
# epoch 27, minibatch 133/133, validation error 32.393939 %
#      epoch 27, minibatch 133/133, test error of best model 32.555556 %
# training @ iter = 3600
# training @ iter = 3700
# epoch 28, minibatch 133/133, validation error 34.222222 %
# training @ iter = 3800
# epoch 29, minibatch 133/133, validation error 36.000000 %
# training @ iter = 3900
# epoch 30, minibatch 133/133, validation error 32.222222 %
#      epoch 30, minibatch 133/133, test error of best model 32.505051 %
# training @ iter = 4000
# training @ iter = 4100
# epoch 31, minibatch 133/133, validation error 32.060606 %
#      epoch 31, minibatch 133/133, test error of best model 32.393939 %
# training @ iter = 4200
# epoch 32, minibatch 133/133, validation error 31.949495 %
#      epoch 32, minibatch 133/133, test error of best model 32.272727 %
# training @ iter = 4300
# epoch 33, minibatch 133/133, validation error 31.868687 %
#      epoch 33, minibatch 133/133, test error of best model 32.252525 %
# training @ iter = 4400
# training @ iter = 4500
# epoch 34, minibatch 133/133, validation error 31.898990 %
# training @ iter = 4600
# epoch 35, minibatch 133/133, validation error 31.686869 %
#      epoch 35, minibatch 133/133, test error of best model 32.000000 %
# training @ iter = 4700
# epoch 36, minibatch 133/133, validation error 31.606061 %
#      epoch 36, minibatch 133/133, test error of best model 31.838384 %
# training @ iter = 4800
# training @ iter = 4900
# epoch 37, minibatch 133/133, validation error 31.494949 %
#      epoch 37, minibatch 133/133, test error of best model 31.808081 %
# training @ iter = 5000
# epoch 38, minibatch 133/133, validation error 31.505051 %
# training @ iter = 5100
# epoch 39, minibatch 133/133, validation error 31.434343 %
#      epoch 39, minibatch 133/133, test error of best model 31.717172 %
# training @ iter = 5200
# training @ iter = 5300
# epoch 40, minibatch 133/133, validation error 31.494949 %
# training @ iter = 5400
# epoch 41, minibatch 133/133, validation error 31.474747 %
# training @ iter = 5500
# epoch 42, minibatch 133/133, validation error 31.454545 %
# training @ iter = 5600
# training @ iter = 5700
# epoch 43, minibatch 133/133, validation error 31.343434 %
#      epoch 43, minibatch 133/133, test error of best model 31.414141 %
# training @ iter = 5800
# epoch 44, minibatch 133/133, validation error 31.363636 %
# training @ iter = 5900
# epoch 45, minibatch 133/133, validation error 31.343434 %
# training @ iter = 6000
# training @ iter = 6100
# epoch 46, minibatch 133/133, validation error 31.262626 %
#      epoch 46, minibatch 133/133, test error of best model 31.434343 %
# training @ iter = 6200
# epoch 47, minibatch 133/133, validation error 31.313131 %
# training @ iter = 6300
# epoch 48, minibatch 133/133, validation error 31.323232 %
# training @ iter = 6400
# training @ iter = 6500
# epoch 49, minibatch 133/133, validation error 31.292929 %
# training @ iter = 6600
# epoch 50, minibatch 133/133, validation error 31.303030 %
# training @ iter = 6700
# epoch 51, minibatch 133/133, validation error 31.303030 %
# training @ iter = 6800
# training @ iter = 6900
# epoch 52, minibatch 133/133, validation error 31.313131 %
# training @ iter = 7000
# epoch 53, minibatch 133/133, validation error 31.353535 %
# training @ iter = 7100
# epoch 54, minibatch 133/133, validation error 31.373737 %
# training @ iter = 7200
# training @ iter = 7300
# epoch 55, minibatch 133/133, validation error 31.373737 %
# training @ iter = 7400
# epoch 56, minibatch 133/133, validation error 31.383838 %
# training @ iter = 7500
# epoch 57, minibatch 133/133, validation error 31.393939 %
# training @ iter = 7600
# training @ iter = 7700
# epoch 58, minibatch 133/133, validation error 31.424242 %
# training @ iter = 7800
# epoch 59, minibatch 133/133, validation error 31.373737 %
# training @ iter = 7900
# epoch 60, minibatch 133/133, validation error 31.353535 %
# training @ iter = 8000
# training @ iter = 8100
# epoch 61, minibatch 133/133, validation error 31.333333 %
# training @ iter = 8200
# epoch 62, minibatch 133/133, validation error 31.333333 %
# training @ iter = 8300
# epoch 63, minibatch 133/133, validation error 31.333333 %
# training @ iter = 8400
# training @ iter = 8500
# epoch 64, minibatch 133/133, validation error 31.333333 %
# training @ iter = 8600
# epoch 65, minibatch 133/133, validation error 31.303030 %
# training @ iter = 8700
# epoch 66, minibatch 133/133, validation error 31.323232 %
# training @ iter = 8800
# training @ iter = 8900
# epoch 67, minibatch 133/133, validation error 31.313131 %
# training @ iter = 9000
# epoch 68, minibatch 133/133, validation error 31.333333 %
# training @ iter = 9100
# epoch 69, minibatch 133/133, validation error 31.303030 %
# training @ iter = 9200
# training @ iter = 9300
# epoch 70, minibatch 133/133, validation error 31.292929 %
# training @ iter = 9400
# epoch 71, minibatch 133/133, validation error 31.303030 %
# training @ iter = 9500
# epoch 72, minibatch 133/133, validation error 31.252525 %
#      epoch 72, minibatch 133/133, test error of best model 31.424242 %
# training @ iter = 9600
# training @ iter = 9700
# epoch 73, minibatch 133/133, validation error 31.292929 %
# training @ iter = 9800
# epoch 74, minibatch 133/133, validation error 31.313131 %
# training @ iter = 9900
# epoch 75, minibatch 133/133, validation error 31.353535 %
# training @ iter = 10000
# Optimization complete.
# Best validation score of 31.252525 % obtained at iteration 9576, with test performance 31.424242 %
# The code for file hw3.py ran for 30.57m

# %% [markdown]
# ### Problem 2: Bullet 2: Augmentation by rotation

# %% [markdown]
# Show a 4*4 figure of 16 input images with this augmentation

# %%
from hw3_utils import load_data
from hw3 import rotate_image
# %matplotlib inline
axarr = plt.subplots(4,4)[1]
for i in range(4):
    for j in range(4):
        plt.axes(axarr[i,j])
        rotate_image(img = datasets[0][0][i*4+j], imgplot = True)

# %% [markdown]
# Implement the neural network with this augmentation, show the improvement

# %%
from hw3 import test_lenet_rotation
test_lenet_rotation(datasets, learning_rate=0.05, n_epochs=200,nkerns=[32, 64], batch_size=300, activation = T.nnet.relu)
# Out:
# ... building the model
# ... training
# training @ iter = 0
# training @ iter = 100
# epoch 1, minibatch 133/133, validation error 75.838384 %
#      epoch 1, minibatch 133/133, test error of best model 75.020202 %
# training @ iter = 200
# epoch 2, minibatch 133/133, validation error 63.090909 %
#      epoch 2, minibatch 133/133, test error of best model 62.393939 %
# training @ iter = 300
# epoch 3, minibatch 133/133, validation error 58.636364 %
#      epoch 3, minibatch 133/133, test error of best model 57.818182 %
# training @ iter = 400
# training @ iter = 500
# epoch 4, minibatch 133/133, validation error 55.121212 %
#      epoch 4, minibatch 133/133, test error of best model 55.202020 %
# training @ iter = 600
# epoch 5, minibatch 133/133, validation error 52.151515 %
#      epoch 5, minibatch 133/133, test error of best model 52.313131 %
# training @ iter = 700
# epoch 6, minibatch 133/133, validation error 49.363636 %
#      epoch 6, minibatch 133/133, test error of best model 49.595960 %
# training @ iter = 800
# training @ iter = 900
# epoch 7, minibatch 133/133, validation error 47.202020 %
#      epoch 7, minibatch 133/133, test error of best model 46.949495 %
# training @ iter = 1000
# epoch 8, minibatch 133/133, validation error 45.353535 %
#      epoch 8, minibatch 133/133, test error of best model 45.151515 %
# training @ iter = 1100
# epoch 9, minibatch 133/133, validation error 43.636364 %
#      epoch 9, minibatch 133/133, test error of best model 43.090909 %
# training @ iter = 1200
# training @ iter = 1300
# epoch 10, minibatch 133/133, validation error 41.515152 %
#      epoch 10, minibatch 133/133, test error of best model 41.131313 %
# training @ iter = 1400
# epoch 11, minibatch 133/133, validation error 40.020202 %
#      epoch 11, minibatch 133/133, test error of best model 40.111111 %
# training @ iter = 1500
# epoch 12, minibatch 133/133, validation error 38.838384 %
#      epoch 12, minibatch 133/133, test error of best model 38.828283 %
# training @ iter = 1600
# training @ iter = 1700
# epoch 13, minibatch 133/133, validation error 37.676768 %
#      epoch 13, minibatch 133/133, test error of best model 37.737374 %
# training @ iter = 1800
# epoch 14, minibatch 133/133, validation error 36.949495 %
#      epoch 14, minibatch 133/133, test error of best model 36.979798 %
# training @ iter = 1900
# epoch 15, minibatch 133/133, validation error 37.131313 %
# training @ iter = 2000
# training @ iter = 2100
# epoch 16, minibatch 133/133, validation error 36.323232 %
#      epoch 16, minibatch 133/133, test error of best model 36.292929 %
# training @ iter = 2200
# epoch 17, minibatch 133/133, validation error 36.848485 %
# training @ iter = 2300
# epoch 18, minibatch 133/133, validation error 38.020202 %
# training @ iter = 2400
# training @ iter = 2500
# epoch 19, minibatch 133/133, validation error 34.030303 %
#      epoch 19, minibatch 133/133, test error of best model 34.010101 %
# training @ iter = 2600
# epoch 20, minibatch 133/133, validation error 36.707071 %
# training @ iter = 2700
# epoch 21, minibatch 133/133, validation error 37.555556 %
# training @ iter = 2800
# training @ iter = 2900
# epoch 22, minibatch 133/133, validation error 34.393939 %
# training @ iter = 3000
# epoch 23, minibatch 133/133, validation error 36.252525 %
# training @ iter = 3100
# epoch 24, minibatch 133/133, validation error 34.131313 %
# training @ iter = 3200
# training @ iter = 3300
# epoch 25, minibatch 133/133, validation error 34.666667 %
# training @ iter = 3400
# epoch 26, minibatch 133/133, validation error 34.292929 %
# training @ iter = 3500
# epoch 27, minibatch 133/133, validation error 32.969697 %
#      epoch 27, minibatch 133/133, test error of best model 33.040404 %
# training @ iter = 3600
# training @ iter = 3700
# epoch 28, minibatch 133/133, validation error 35.010101 %
# training @ iter = 3800
# epoch 29, minibatch 133/133, validation error 33.979798 %
# training @ iter = 3900
# epoch 30, minibatch 133/133, validation error 33.171717 %
# training @ iter = 4000
# training @ iter = 4100
# epoch 31, minibatch 133/133, validation error 33.292929 %
# training @ iter = 4200
# epoch 32, minibatch 133/133, validation error 32.848485 %
#      epoch 32, minibatch 133/133, test error of best model 32.595960 %
# training @ iter = 4300
# epoch 33, minibatch 133/133, validation error 32.676768 %
#      epoch 33, minibatch 133/133, test error of best model 32.535354 %
# training @ iter = 4400
# training @ iter = 4500
# epoch 34, minibatch 133/133, validation error 32.595960 %
#      epoch 34, minibatch 133/133, test error of best model 32.202020 %
# training @ iter = 4600
# epoch 35, minibatch 133/133, validation error 32.484848 %
#      epoch 35, minibatch 133/133, test error of best model 32.060606 %
# training @ iter = 4700
# epoch 36, minibatch 133/133, validation error 32.373737 %
#      epoch 36, minibatch 133/133, test error of best model 31.979798 %
# training @ iter = 4800
# training @ iter = 4900
# epoch 37, minibatch 133/133, validation error 32.282828 %
#      epoch 37, minibatch 133/133, test error of best model 31.898990 %
# training @ iter = 5000
# epoch 38, minibatch 133/133, validation error 32.161616 %
#      epoch 38, minibatch 133/133, test error of best model 31.737374 %
# training @ iter = 5100
# epoch 39, minibatch 133/133, validation error 32.060606 %
#      epoch 39, minibatch 133/133, test error of best model 31.686869 %
# training @ iter = 5200
# training @ iter = 5300
# epoch 40, minibatch 133/133, validation error 31.919192 %
#      epoch 40, minibatch 133/133, test error of best model 31.626263 %
# training @ iter = 5400
# epoch 41, minibatch 133/133, validation error 31.888889 %
#      epoch 41, minibatch 133/133, test error of best model 31.595960 %
# training @ iter = 5500
# epoch 42, minibatch 133/133, validation error 31.929293 %
# training @ iter = 5600
# training @ iter = 5700
# epoch 43, minibatch 133/133, validation error 31.848485 %
#      epoch 43, minibatch 133/133, test error of best model 31.555556 %
# training @ iter = 5800
# epoch 44, minibatch 133/133, validation error 31.878788 %
# training @ iter = 5900
# epoch 45, minibatch 133/133, validation error 31.878788 %
# training @ iter = 6000
# training @ iter = 6100
# epoch 46, minibatch 133/133, validation error 31.717172 %
#      epoch 46, minibatch 133/133, test error of best model 31.494949 %
# training @ iter = 6200
# epoch 47, minibatch 133/133, validation error 31.717172 %
#      epoch 47, minibatch 133/133, test error of best model 31.505051 %
# training @ iter = 6300
# epoch 48, minibatch 133/133, validation error 31.696970 %
#      epoch 48, minibatch 133/133, test error of best model 31.565657 %
# training @ iter = 6400
# training @ iter = 6500
# epoch 49, minibatch 133/133, validation error 31.646465 %
#      epoch 49, minibatch 133/133, test error of best model 31.595960 %
# training @ iter = 6600
# epoch 50, minibatch 133/133, validation error 31.636364 %
#      epoch 50, minibatch 133/133, test error of best model 31.606061 %
# training @ iter = 6700
# epoch 51, minibatch 133/133, validation error 31.646465 %
# training @ iter = 6800
# training @ iter = 6900
# epoch 52, minibatch 133/133, validation error 31.656566 %
# training @ iter = 7000
# epoch 53, minibatch 133/133, validation error 31.646465 %
# training @ iter = 7100
# epoch 54, minibatch 133/133, validation error 31.626263 %
#      epoch 54, minibatch 133/133, test error of best model 31.454545 %
# training @ iter = 7200
# training @ iter = 7300
# epoch 55, minibatch 133/133, validation error 31.626263 %
# training @ iter = 7400
# epoch 56, minibatch 133/133, validation error 31.606061 %
#      epoch 56, minibatch 133/133, test error of best model 31.535354 %
# training @ iter = 7500
# epoch 57, minibatch 133/133, validation error 31.595960 %
#      epoch 57, minibatch 133/133, test error of best model 31.545455 %
# training @ iter = 7600
# training @ iter = 7700
# epoch 58, minibatch 133/133, validation error 31.636364 %
# training @ iter = 7800
# epoch 59, minibatch 133/133, validation error 31.626263 %
# training @ iter = 7900
# epoch 60, minibatch 133/133, validation error 31.616162 %
# training @ iter = 8000
# training @ iter = 8100
# epoch 61, minibatch 133/133, validation error 31.585859 %
#      epoch 61, minibatch 133/133, test error of best model 31.585859 %
# training @ iter = 8200
# epoch 62, minibatch 133/133, validation error 31.525253 %
#      epoch 62, minibatch 133/133, test error of best model 31.565657 %
# training @ iter = 8300
# epoch 63, minibatch 133/133, validation error 31.555556 %
# training @ iter = 8400
# training @ iter = 8500
# epoch 64, minibatch 133/133, validation error 31.535354 %
# training @ iter = 8600
# epoch 65, minibatch 133/133, validation error 31.575758 %
# training @ iter = 8700
# epoch 66, minibatch 133/133, validation error 31.545455 %
# training @ iter = 8800
# training @ iter = 8900
# epoch 67, minibatch 133/133, validation error 31.575758 %
# training @ iter = 9000
# epoch 68, minibatch 133/133, validation error 31.585859 %
# training @ iter = 9100
# epoch 69, minibatch 133/133, validation error 31.616162 %
# training @ iter = 9200
# training @ iter = 9300
# epoch 70, minibatch 133/133, validation error 31.646465 %
# training @ iter = 9400
# epoch 71, minibatch 133/133, validation error 31.646465 %
# training @ iter = 9500
# epoch 72, minibatch 133/133, validation error 31.646465 %
# training @ iter = 9600
# training @ iter = 9700
# epoch 73, minibatch 133/133, validation error 31.646465 %
# training @ iter = 9800
# epoch 74, minibatch 133/133, validation error 31.616162 %
# training @ iter = 9900
# epoch 75, minibatch 133/133, validation error 31.595960 %
# training @ iter = 10000
# Optimization complete.
# Best validation score of 31.525253 % obtained at iteration 8246, with test performance 31.565657 %
# The code for file hw3.py ran for 30.20m

# %% [markdown]
# ### Problem 2: Bullet 3: Augmentation by flipping

# %% [markdown]
# Show a 4*4 figure of 16 input images with this augmentation

# %%
from hw3_utils import load_data
from hw3 import flip_image

# %matplotlib inline
axarr = plt.subplots(4,4)[1]
for i in range(4):
    for j in range(4):
        plt.axes(axarr[i,j])
        flip_image(img = datasets[0][0][i*4+j], imgplot = True)

# %% [markdown]
# Implement the neural network with this augmentation, show the improvement

# %%
from hw3 import test_lenet_flip
test_lenet_flip(datasets, learning_rate=0.05, n_epochs=200,nkerns=[32, 64], batch_size=300, activation = T.nnet.relu)
# Out:
# ... building the model
# ... training
# training @ iter = 0
# training @ iter = 100
# epoch 1, minibatch 133/133, validation error 76.161616 %
#      epoch 1, minibatch 133/133, test error of best model 75.545455 %
# training @ iter = 200
# epoch 2, minibatch 133/133, validation error 63.050505 %
#      epoch 2, minibatch 133/133, test error of best model 62.454545 %
# training @ iter = 300
# epoch 3, minibatch 133/133, validation error 58.636364 %
#      epoch 3, minibatch 133/133, test error of best model 57.797980 %
# training @ iter = 400
# training @ iter = 500
# epoch 4, minibatch 133/133, validation error 55.111111 %
#      epoch 4, minibatch 133/133, test error of best model 55.282828 %
# training @ iter = 600
# epoch 5, minibatch 133/133, validation error 52.252525 %
#      epoch 5, minibatch 133/133, test error of best model 52.171717 %
# training @ iter = 700
# epoch 6, minibatch 133/133, validation error 49.515152 %
#      epoch 6, minibatch 133/133, test error of best model 49.565657 %
# training @ iter = 800
# training @ iter = 900
# epoch 7, minibatch 133/133, validation error 47.323232 %
#      epoch 7, minibatch 133/133, test error of best model 47.171717 %
# training @ iter = 1000
# epoch 8, minibatch 133/133, validation error 45.232323 %
#      epoch 8, minibatch 133/133, test error of best model 45.393939 %
# training @ iter = 1100
# epoch 9, minibatch 133/133, validation error 42.979798 %
#      epoch 9, minibatch 133/133, test error of best model 42.828283 %
# training @ iter = 1200
# training @ iter = 1300
# epoch 10, minibatch 133/133, validation error 41.434343 %
#      epoch 10, minibatch 133/133, test error of best model 41.232323 %
# training @ iter = 1400
# epoch 11, minibatch 133/133, validation error 40.131313 %
#      epoch 11, minibatch 133/133, test error of best model 39.919192 %
# training @ iter = 1500
# epoch 12, minibatch 133/133, validation error 38.535354 %
#      epoch 12, minibatch 133/133, test error of best model 38.272727 %
# training @ iter = 1600
# training @ iter = 1700
# epoch 13, minibatch 133/133, validation error 37.737374 %
#      epoch 13, minibatch 133/133, test error of best model 37.313131 %
# training @ iter = 1800
# epoch 14, minibatch 133/133, validation error 37.111111 %
#      epoch 14, minibatch 133/133, test error of best model 36.767677 %
# training @ iter = 1900
# epoch 15, minibatch 133/133, validation error 36.767677 %
#      epoch 15, minibatch 133/133, test error of best model 36.191919 %
# training @ iter = 2000
# training @ iter = 2100
# epoch 16, minibatch 133/133, validation error 36.363636 %
#      epoch 16, minibatch 133/133, test error of best model 36.040404 %
# training @ iter = 2200
# epoch 17, minibatch 133/133, validation error 36.171717 %
#      epoch 17, minibatch 133/133, test error of best model 35.474747 %
# training @ iter = 2300
# epoch 18, minibatch 133/133, validation error 36.909091 %
# training @ iter = 2400
# training @ iter = 2500
# epoch 19, minibatch 133/133, validation error 38.191919 %
# training @ iter = 2600
# epoch 20, minibatch 133/133, validation error 35.888889 %
#      epoch 20, minibatch 133/133, test error of best model 35.969697 %
# training @ iter = 2700
# epoch 21, minibatch 133/133, validation error 33.878788 %
#      epoch 21, minibatch 133/133, test error of best model 33.383838 %
# training @ iter = 2800
# training @ iter = 2900
# epoch 22, minibatch 133/133, validation error 35.666667 %
# training @ iter = 3000
# epoch 23, minibatch 133/133, validation error 35.252525 %
# training @ iter = 3100
# epoch 24, minibatch 133/133, validation error 33.161616 %
#      epoch 24, minibatch 133/133, test error of best model 32.989899 %
# training @ iter = 3200
# training @ iter = 3300
# epoch 25, minibatch 133/133, validation error 34.848485 %
# training @ iter = 3400
# epoch 26, minibatch 133/133, validation error 33.525253 %
# training @ iter = 3500
# epoch 27, minibatch 133/133, validation error 32.474747 %
#      epoch 27, minibatch 133/133, test error of best model 33.131313 %
# training @ iter = 3600
# training @ iter = 3700
# epoch 28, minibatch 133/133, validation error 33.868687 %
# training @ iter = 3800
# epoch 29, minibatch 133/133, validation error 31.666667 %
#      epoch 29, minibatch 133/133, test error of best model 32.575758 %
# training @ iter = 3900
# epoch 30, minibatch 133/133, validation error 31.565657 %
#      epoch 30, minibatch 133/133, test error of best model 32.707071 %
# training @ iter = 4000
# training @ iter = 4100
# epoch 31, minibatch 133/133, validation error 31.848485 %
# training @ iter = 4200
# epoch 32, minibatch 133/133, validation error 31.333333 %
#      epoch 32, minibatch 133/133, test error of best model 32.292929 %
# training @ iter = 4300
# epoch 33, minibatch 133/133, validation error 31.383838 %
# training @ iter = 4400
# training @ iter = 4500
# epoch 34, minibatch 133/133, validation error 31.212121 %
#      epoch 34, minibatch 133/133, test error of best model 32.191919 %
# training @ iter = 4600
# epoch 35, minibatch 133/133, validation error 31.060606 %
#      epoch 35, minibatch 133/133, test error of best model 31.929293 %
# training @ iter = 4700
# epoch 36, minibatch 133/133, validation error 31.101010 %
# training @ iter = 4800
# training @ iter = 4900
# epoch 37, minibatch 133/133, validation error 30.979798 %
#      epoch 37, minibatch 133/133, test error of best model 31.808081 %
# training @ iter = 5000
# epoch 38, minibatch 133/133, validation error 31.010101 %
# training @ iter = 5100
# epoch 39, minibatch 133/133, validation error 30.838384 %
#      epoch 39, minibatch 133/133, test error of best model 31.585859 %
# training @ iter = 5200
# training @ iter = 5300
# epoch 40, minibatch 133/133, validation error 30.838384 %
# training @ iter = 5400
# epoch 41, minibatch 133/133, validation error 30.787879 %
#      epoch 41, minibatch 133/133, test error of best model 31.565657 %
# training @ iter = 5500
# epoch 42, minibatch 133/133, validation error 30.818182 %
# training @ iter = 5600
# training @ iter = 5700
# epoch 43, minibatch 133/133, validation error 30.838384 %
# training @ iter = 5800
# epoch 44, minibatch 133/133, validation error 30.868687 %
# training @ iter = 5900
# epoch 45, minibatch 133/133, validation error 30.898990 %
# training @ iter = 6000
# training @ iter = 6100
# epoch 46, minibatch 133/133, validation error 30.878788 %
# training @ iter = 6200
# epoch 47, minibatch 133/133, validation error 30.858586 %
# training @ iter = 6300
# epoch 48, minibatch 133/133, validation error 30.797980 %
# training @ iter = 6400
# training @ iter = 6500
# epoch 49, minibatch 133/133, validation error 30.818182 %
# training @ iter = 6600
# epoch 50, minibatch 133/133, validation error 30.787879 %
# training @ iter = 6700
# epoch 51, minibatch 133/133, validation error 30.777778 %
#      epoch 51, minibatch 133/133, test error of best model 31.424242 %
# training @ iter = 6800
# training @ iter = 6900
# epoch 52, minibatch 133/133, validation error 30.797980 %
# training @ iter = 7000
# epoch 53, minibatch 133/133, validation error 30.797980 %
# training @ iter = 7100
# epoch 54, minibatch 133/133, validation error 30.797980 %
# training @ iter = 7200
# training @ iter = 7300
# epoch 55, minibatch 133/133, validation error 30.777778 %
#      epoch 55, minibatch 133/133, test error of best model 31.303030 %
# training @ iter = 7400
# epoch 56, minibatch 133/133, validation error 30.696970 %
#      epoch 56, minibatch 133/133, test error of best model 31.303030 %
# training @ iter = 7500
# epoch 57, minibatch 133/133, validation error 30.676768 %
#      epoch 57, minibatch 133/133, test error of best model 31.353535 %
# training @ iter = 7600
# training @ iter = 7700
# epoch 58, minibatch 133/133, validation error 30.707071 %
# training @ iter = 7800
# epoch 59, minibatch 133/133, validation error 30.676768 %
# training @ iter = 7900
# epoch 60, minibatch 133/133, validation error 30.717172 %
# training @ iter = 8000
# training @ iter = 8100
# epoch 61, minibatch 133/133, validation error 30.737374 %
# training @ iter = 8200
# epoch 62, minibatch 133/133, validation error 30.757576 %
# training @ iter = 8300
# epoch 63, minibatch 133/133, validation error 30.727273 %
# training @ iter = 8400
# training @ iter = 8500
# epoch 64, minibatch 133/133, validation error 30.727273 %
# training @ iter = 8600
# epoch 65, minibatch 133/133, validation error 30.696970 %
# training @ iter = 8700
# epoch 66, minibatch 133/133, validation error 30.676768 %
# training @ iter = 8800
# training @ iter = 8900
# epoch 67, minibatch 133/133, validation error 30.676768 %
# training @ iter = 9000
# epoch 68, minibatch 133/133, validation error 30.636364 %
#      epoch 68, minibatch 133/133, test error of best model 31.232323 %
# training @ iter = 9100
# epoch 69, minibatch 133/133, validation error 30.616162 %
#      epoch 69, minibatch 133/133, test error of best model 31.262626 %
# training @ iter = 9200
# training @ iter = 9300
# epoch 70, minibatch 133/133, validation error 30.585859 %
#      epoch 70, minibatch 133/133, test error of best model 31.232323 %
# training @ iter = 9400
# epoch 71, minibatch 133/133, validation error 30.595960 %
# training @ iter = 9500
# epoch 72, minibatch 133/133, validation error 30.616162 %
# training @ iter = 9600
# training @ iter = 9700
# epoch 73, minibatch 133/133, validation error 30.616162 %
# training @ iter = 9800
# epoch 74, minibatch 133/133, validation error 30.585859 %
# training @ iter = 9900
# epoch 75, minibatch 133/133, validation error 30.565657 %
#      epoch 75, minibatch 133/133, test error of best model 31.303030 %
# training @ iter = 10000
# Optimization complete.
# Best validation score of 30.565657 % obtained at iteration 9975, with test performance 31.303030 %
# The code for file hw3.py ran for 30.19m

# %% [markdown]
# ### Problem 2: Bullet 4: Augmentation by injecting noise into input

# %% [markdown]
# Show a 4*4 figure of 16 input images with this augmentation

# %%
from hw3_utils import load_data
from hw3 import noise_injection
# %matplotlib inline
axarr = plt.subplots(4,4)[1]
for i in range(4):
    for j in range(4):
        plt.axes(axarr[i,j])
        noise_injection(img = datasets[0][0][i*4+j], imgplot = True)

# %% [markdown]
# Implement the neural network with this augmentation, show the improvement

# %%
from hw3 import test_lenet_inject_noise_input
test_lenet_inject_noise_input(datasets, learning_rate=0.05, n_epochs=200,nkerns=[32, 64], batch_size=300, activation = T.nnet.relu)
# Out:
# ... building the model
# ... training
# training @ iter = 0
# training @ iter = 100
# epoch 1, minibatch 133/133, validation error 75.757576 %
#      epoch 1, minibatch 133/133, test error of best model 74.929293 %
# training @ iter = 200
# epoch 2, minibatch 133/133, validation error 63.161616 %
#      epoch 2, minibatch 133/133, test error of best model 62.363636 %
# training @ iter = 300
# epoch 3, minibatch 133/133, validation error 58.636364 %
#      epoch 3, minibatch 133/133, test error of best model 57.656566 %
# training @ iter = 400
# training @ iter = 500
# epoch 4, minibatch 133/133, validation error 55.181818 %
#      epoch 4, minibatch 133/133, test error of best model 55.232323 %
# training @ iter = 600
# epoch 5, minibatch 133/133, validation error 52.222222 %
#      epoch 5, minibatch 133/133, test error of best model 52.202020 %
# training @ iter = 700
# epoch 6, minibatch 133/133, validation error 49.575758 %
#      epoch 6, minibatch 133/133, test error of best model 49.505051 %
# training @ iter = 800
# training @ iter = 900
# epoch 7, minibatch 133/133, validation error 47.343434 %
#      epoch 7, minibatch 133/133, test error of best model 47.191919 %
# training @ iter = 1000
# epoch 8, minibatch 133/133, validation error 45.343434 %
#      epoch 8, minibatch 133/133, test error of best model 45.373737 %
# training @ iter = 1100
# epoch 9, minibatch 133/133, validation error 43.222222 %
#      epoch 9, minibatch 133/133, test error of best model 43.070707 %
# training @ iter = 1200
# training @ iter = 1300
# epoch 10, minibatch 133/133, validation error 41.646465 %
#      epoch 10, minibatch 133/133, test error of best model 41.585859 %
# training @ iter = 1400
# epoch 11, minibatch 133/133, validation error 41.383838 %
#      epoch 11, minibatch 133/133, test error of best model 41.535354 %
# training @ iter = 1500
# epoch 12, minibatch 133/133, validation error 38.888889 %
#      epoch 12, minibatch 133/133, test error of best model 38.515152 %
# training @ iter = 1600
# training @ iter = 1700
# epoch 13, minibatch 133/133, validation error 37.626263 %
#      epoch 13, minibatch 133/133, test error of best model 37.303030 %
# training @ iter = 1800
# epoch 14, minibatch 133/133, validation error 36.808081 %
#      epoch 14, minibatch 133/133, test error of best model 36.686869 %
# training @ iter = 1900
# epoch 15, minibatch 133/133, validation error 36.828283 %
# training @ iter = 2000
# training @ iter = 2100
# epoch 16, minibatch 133/133, validation error 36.797980 %
#      epoch 16, minibatch 133/133, test error of best model 36.646465 %
# training @ iter = 2200
# epoch 17, minibatch 133/133, validation error 35.767677 %
#      epoch 17, minibatch 133/133, test error of best model 34.969697 %
# training @ iter = 2300
# epoch 18, minibatch 133/133, validation error 36.525253 %
# training @ iter = 2400
# training @ iter = 2500
# epoch 19, minibatch 133/133, validation error 39.090909 %
# training @ iter = 2600
# epoch 20, minibatch 133/133, validation error 33.818182 %
#      epoch 20, minibatch 133/133, test error of best model 33.949495 %
# training @ iter = 2700
# epoch 21, minibatch 133/133, validation error 35.818182 %
# training @ iter = 2800
# training @ iter = 2900
# epoch 22, minibatch 133/133, validation error 36.111111 %
# training @ iter = 3000
# epoch 23, minibatch 133/133, validation error 36.131313 %
# training @ iter = 3100
# epoch 24, minibatch 133/133, validation error 33.020202 %
#      epoch 24, minibatch 133/133, test error of best model 33.242424 %
# training @ iter = 3200
# training @ iter = 3300
# epoch 25, minibatch 133/133, validation error 33.838384 %
# training @ iter = 3400
# epoch 26, minibatch 133/133, validation error 34.909091 %
# training @ iter = 3500
# epoch 27, minibatch 133/133, validation error 32.080808 %
#      epoch 27, minibatch 133/133, test error of best model 32.929293 %
# training @ iter = 3600
# training @ iter = 3700
# epoch 28, minibatch 133/133, validation error 32.323232 %
# training @ iter = 3800
# epoch 29, minibatch 133/133, validation error 32.515152 %
# training @ iter = 3900
# epoch 30, minibatch 133/133, validation error 31.909091 %
#      epoch 30, minibatch 133/133, test error of best model 32.646465 %
# training @ iter = 4000
# training @ iter = 4100
# epoch 31, minibatch 133/133, validation error 31.727273 %
#      epoch 31, minibatch 133/133, test error of best model 32.848485 %
# training @ iter = 4200
# epoch 32, minibatch 133/133, validation error 31.313131 %
#      epoch 32, minibatch 133/133, test error of best model 32.202020 %
# training @ iter = 4300
# epoch 33, minibatch 133/133, validation error 31.282828 %
#      epoch 33, minibatch 133/133, test error of best model 32.303030 %
# training @ iter = 4400
# training @ iter = 4500
# epoch 34, minibatch 133/133, validation error 31.151515 %
#      epoch 34, minibatch 133/133, test error of best model 32.040404 %
# training @ iter = 4600
# epoch 35, minibatch 133/133, validation error 30.858586 %
#      epoch 35, minibatch 133/133, test error of best model 31.949495 %
# training @ iter = 4700
# epoch 36, minibatch 133/133, validation error 30.737374 %
#      epoch 36, minibatch 133/133, test error of best model 31.939394 %
# training @ iter = 4800
# training @ iter = 4900
# epoch 37, minibatch 133/133, validation error 30.737374 %
# training @ iter = 5000
# epoch 38, minibatch 133/133, validation error 30.777778 %
# training @ iter = 5100
# epoch 39, minibatch 133/133, validation error 30.707071 %
#      epoch 39, minibatch 133/133, test error of best model 31.818182 %
# training @ iter = 5200
# training @ iter = 5300
# epoch 40, minibatch 133/133, validation error 30.676768 %
#      epoch 40, minibatch 133/133, test error of best model 31.767677 %
# training @ iter = 5400
# epoch 41, minibatch 133/133, validation error 30.676768 %
# training @ iter = 5500
# epoch 42, minibatch 133/133, validation error 30.707071 %
# training @ iter = 5600
# training @ iter = 5700
# epoch 43, minibatch 133/133, validation error 30.737374 %
# training @ iter = 5800
# epoch 44, minibatch 133/133, validation error 30.636364 %
#      epoch 44, minibatch 133/133, test error of best model 31.646465 %
# training @ iter = 5900
# epoch 45, minibatch 133/133, validation error 30.656566 %
# training @ iter = 6000
# training @ iter = 6100
# epoch 46, minibatch 133/133, validation error 30.676768 %
# training @ iter = 6200
# epoch 47, minibatch 133/133, validation error 30.757576 %
# training @ iter = 6300
# epoch 48, minibatch 133/133, validation error 30.737374 %
# training @ iter = 6400
# training @ iter = 6500
# epoch 49, minibatch 133/133, validation error 30.717172 %
# training @ iter = 6600
# epoch 50, minibatch 133/133, validation error 30.787879 %
# training @ iter = 6700
# epoch 51, minibatch 133/133, validation error 30.797980 %
# training @ iter = 6800
# training @ iter = 6900
# epoch 52, minibatch 133/133, validation error 30.797980 %
# training @ iter = 7000
# epoch 53, minibatch 133/133, validation error 30.777778 %
# training @ iter = 7100
# epoch 54, minibatch 133/133, validation error 30.686869 %
# training @ iter = 7200
# training @ iter = 7300
# epoch 55, minibatch 133/133, validation error 30.666667 %
# training @ iter = 7400
# epoch 56, minibatch 133/133, validation error 30.606061 %
#      epoch 56, minibatch 133/133, test error of best model 31.525253 %
# training @ iter = 7500
# epoch 57, minibatch 133/133, validation error 30.666667 %
# training @ iter = 7600
# training @ iter = 7700
# epoch 58, minibatch 133/133, validation error 30.686869 %
# training @ iter = 7800
# epoch 59, minibatch 133/133, validation error 30.717172 %
# training @ iter = 7900
# epoch 60, minibatch 133/133, validation error 30.757576 %
# training @ iter = 8000
# training @ iter = 8100
# epoch 61, minibatch 133/133, validation error 30.747475 %
# training @ iter = 8200
# epoch 62, minibatch 133/133, validation error 30.717172 %
# training @ iter = 8300
# epoch 63, minibatch 133/133, validation error 30.707071 %
# training @ iter = 8400
# training @ iter = 8500
# epoch 64, minibatch 133/133, validation error 30.666667 %
# training @ iter = 8600
# epoch 65, minibatch 133/133, validation error 30.696970 %
# training @ iter = 8700
# epoch 66, minibatch 133/133, validation error 30.666667 %
# training @ iter = 8800
# training @ iter = 8900
# epoch 67, minibatch 133/133, validation error 30.656566 %
# training @ iter = 9000
# epoch 68, minibatch 133/133, validation error 30.676768 %
# training @ iter = 9100
# epoch 69, minibatch 133/133, validation error 30.696970 %
# training @ iter = 9200
# training @ iter = 9300
# epoch 70, minibatch 133/133, validation error 30.666667 %
# training @ iter = 9400
# epoch 71, minibatch 133/133, validation error 30.676768 %
# training @ iter = 9500
# epoch 72, minibatch 133/133, validation error 30.616162 %
# training @ iter = 9600
# training @ iter = 9700
# epoch 73, minibatch 133/133, validation error 30.636364 %
# training @ iter = 9800
# epoch 74, minibatch 133/133, validation error 30.636364 %
# training @ iter = 9900
# epoch 75, minibatch 133/133, validation error 30.585859 %
#      epoch 75, minibatch 133/133, test error of best model 31.464646 %
# training @ iter = 10000
# Optimization complete.
# Best validation score of 30.585859 % obtained at iteration 9975, with test performance 31.464646 %
# The code for file hw3.py ran for 29.93m

# %% [markdown]
# ### Problem 3: Implement your own achritecture to achieve at least 80% testing accuracy on CIFAR-10 test set

# %% [markdown]
# I used BatchNormalization.py from https://github.com/shuuki4/Batch-Normalization.
# I used three convolution layers with batch normalization and momentum for gradient.
# Finally, I get validation error rate around 19% and test error rate round 20%.

# %%
import theano.tensor as T
from hw3 import MY_lenet
MY_lenet(datasets, learning_rate=0.03, n_epochs=200, nkerns=[32, 64,128,256], batch_size=256, activation = T.nnet.relu)
# Out:
# ... building the model
# ... training
# training @ iter = 0
# training @ iter = 100
# epoch 1, minibatch 156/156, validation error 86.588542 %
#      epoch 1, minibatch 156/156, test error of best model 87.039263 %
# training @ iter = 200
# training @ iter = 300
# epoch 2, minibatch 156/156, validation error 85.386619 %
#      epoch 2, minibatch 156/156, test error of best model 85.166266 %
# training @ iter = 400
# epoch 3, minibatch 156/156, validation error 72.796474 %
#      epoch 3, minibatch 156/156, test error of best model 72.135417 %
# training @ iter = 500
# training @ iter = 600
# epoch 4, minibatch 156/156, validation error 63.772035 %
#      epoch 4, minibatch 156/156, test error of best model 63.892228 %
# training @ iter = 700
# epoch 5, minibatch 156/156, validation error 55.689103 %
#      epoch 5, minibatch 156/156, test error of best model 56.430288 %
# training @ iter = 800
# training @ iter = 900
# epoch 6, minibatch 156/156, validation error 50.450721 %
#      epoch 6, minibatch 156/156, test error of best model 50.941506 %
# training @ iter = 1000
# epoch 7, minibatch 156/156, validation error 48.888221 %
#      epoch 7, minibatch 156/156, test error of best model 48.447516 %
# training @ iter = 1100
# training @ iter = 1200
# epoch 8, minibatch 156/156, validation error 46.794872 %
#      epoch 8, minibatch 156/156, test error of best model 46.103766 %
# training @ iter = 1300
# training @ iter = 1400
# epoch 9, minibatch 156/156, validation error 44.000401 %
#      epoch 9, minibatch 156/156, test error of best model 44.340946 %
# training @ iter = 1500
# epoch 10, minibatch 156/156, validation error 42.287660 %
#      epoch 10, minibatch 156/156, test error of best model 42.918670 %
# training @ iter = 1600
# training @ iter = 1700
# epoch 11, minibatch 156/156, validation error 40.244391 %
#      epoch 11, minibatch 156/156, test error of best model 40.404647 %
# training @ iter = 1800
# epoch 12, minibatch 156/156, validation error 36.027644 %
#      epoch 12, minibatch 156/156, test error of best model 35.426683 %
# training @ iter = 1900
# training @ iter = 2000
# epoch 13, minibatch 156/156, validation error 33.663862 %
#      epoch 13, minibatch 156/156, test error of best model 33.092949 %
# training @ iter = 2100
# epoch 14, minibatch 156/156, validation error 31.610577 %
#      epoch 14, minibatch 156/156, test error of best model 31.219952 %
# training @ iter = 2200
# training @ iter = 2300
# epoch 15, minibatch 156/156, validation error 29.987981 %
#      epoch 15, minibatch 156/156, test error of best model 29.907853 %
# training @ iter = 2400
# epoch 16, minibatch 156/156, validation error 28.485577 %
#      epoch 16, minibatch 156/156, test error of best model 28.455529 %
# training @ iter = 2500
# training @ iter = 2600
# epoch 17, minibatch 156/156, validation error 27.363782 %
#      epoch 17, minibatch 156/156, test error of best model 27.373798 %
# training @ iter = 2700
# training @ iter = 2800
# epoch 18, minibatch 156/156, validation error 28.645833 %
# training @ iter = 2900
# epoch 19, minibatch 156/156, validation error 28.986378 %
# training @ iter = 3000
# training @ iter = 3100
# epoch 20, minibatch 156/156, validation error 25.831330 %
#      epoch 20, minibatch 156/156, test error of best model 26.312099 %
# training @ iter = 3200
# epoch 21, minibatch 156/156, validation error 28.355369 %
# training @ iter = 3300
# training @ iter = 3400
# epoch 22, minibatch 156/156, validation error 27.554087 %
# training @ iter = 3500
# epoch 23, minibatch 156/156, validation error 26.121795 %
# training @ iter = 3600
# training @ iter = 3700
# epoch 24, minibatch 156/156, validation error 24.118590 %
#      epoch 24, minibatch 156/156, test error of best model 24.288862 %
# training @ iter = 3800
# epoch 25, minibatch 156/156, validation error 24.489183 %
# training @ iter = 3900
# training @ iter = 4000
# epoch 26, minibatch 156/156, validation error 28.495593 %
# training @ iter = 4100
# training @ iter = 4200
# epoch 27, minibatch 156/156, validation error 24.959936 %
# training @ iter = 4300
# epoch 28, minibatch 156/156, validation error 25.631010 %
# training @ iter = 4400
# training @ iter = 4500
# epoch 29, minibatch 156/156, validation error 31.179888 %
# training @ iter = 4600
# epoch 30, minibatch 156/156, validation error 30.629006 %
# training @ iter = 4700
# training @ iter = 4800
# epoch 31, minibatch 156/156, validation error 24.839744 %
# training @ iter = 4900
# epoch 32, minibatch 156/156, validation error 26.822917 %
# training @ iter = 5000
# training @ iter = 5100
# epoch 33, minibatch 156/156, validation error 27.253606 %
# training @ iter = 5200
# training @ iter = 5300
# epoch 34, minibatch 156/156, validation error 22.455929 %
#      epoch 34, minibatch 156/156, test error of best model 22.836538 %
# training @ iter = 5400
# epoch 35, minibatch 156/156, validation error 22.696314 %
# training @ iter = 5500
# training @ iter = 5600
# epoch 36, minibatch 156/156, validation error 22.666266 %
# training @ iter = 5700
# epoch 37, minibatch 156/156, validation error 26.592548 %
# training @ iter = 5800
# training @ iter = 5900
# epoch 38, minibatch 156/156, validation error 23.377404 %
# training @ iter = 6000
# epoch 39, minibatch 156/156, validation error 25.110176 %
# training @ iter = 6100
# training @ iter = 6200
# epoch 40, minibatch 156/156, validation error 22.265625 %
#      epoch 40, minibatch 156/156, test error of best model 22.495994 %
# training @ iter = 6300
# epoch 41, minibatch 156/156, validation error 22.736378 %
# training @ iter = 6400
# training @ iter = 6500
# epoch 42, minibatch 156/156, validation error 20.462740 %
#      epoch 42, minibatch 156/156, test error of best model 21.113782 %
# training @ iter = 6600
# training @ iter = 6700
# epoch 43, minibatch 156/156, validation error 20.773237 %
# training @ iter = 6800
# epoch 44, minibatch 156/156, validation error 21.324119 %
# training @ iter = 6900
# training @ iter = 7000
# epoch 45, minibatch 156/156, validation error 20.482772 %
# training @ iter = 7100
# epoch 46, minibatch 156/156, validation error 20.462740 %
# training @ iter = 7200
# training @ iter = 7300
# epoch 47, minibatch 156/156, validation error 20.302484 %
#      epoch 47, minibatch 156/156, test error of best model 20.993590 %
# training @ iter = 7400
# epoch 48, minibatch 156/156, validation error 21.023638 %
# training @ iter = 7500
# training @ iter = 7600
# epoch 49, minibatch 156/156, validation error 20.252404 %
#      epoch 49, minibatch 156/156, test error of best model 20.893429 %
# training @ iter = 7700
# epoch 50, minibatch 156/156, validation error 20.302484 %
# training @ iter = 7800
# training @ iter = 7900
# epoch 51, minibatch 156/156, validation error 20.132212 %
#      epoch 51, minibatch 156/156, test error of best model 20.823317 %
# training @ iter = 8000
# training @ iter = 8100
# epoch 52, minibatch 156/156, validation error 20.242388 %
# training @ iter = 8200
# epoch 53, minibatch 156/156, validation error 20.212340 %
# training @ iter = 8300
# training @ iter = 8400
# epoch 54, minibatch 156/156, validation error 20.232372 %
# training @ iter = 8500
# epoch 55, minibatch 156/156, validation error 20.212340 %
# training @ iter = 8600
# training @ iter = 8700
# epoch 56, minibatch 156/156, validation error 20.222356 %
# training @ iter = 8800
# epoch 57, minibatch 156/156, validation error 20.202324 %
# training @ iter = 8900
# training @ iter = 9000
# epoch 58, minibatch 156/156, validation error 20.222356 %
# training @ iter = 9100
# training @ iter = 9200
# epoch 59, minibatch 156/156, validation error 20.132212 %
# training @ iter = 9300
# epoch 60, minibatch 156/156, validation error 20.112179 %
#      epoch 60, minibatch 156/156, test error of best model 20.903446 %
# training @ iter = 9400
# training @ iter = 9500
# epoch 61, minibatch 156/156, validation error 20.102163 %
#      epoch 61, minibatch 156/156, test error of best model 20.863381 %
# training @ iter = 9600
# epoch 62, minibatch 156/156, validation error 20.092147 %
#      epoch 62, minibatch 156/156, test error of best model 20.893429 %
# training @ iter = 9700
# training @ iter = 9800
# epoch 63, minibatch 156/156, validation error 20.072115 %
#      epoch 63, minibatch 156/156, test error of best model 20.873397 %
# training @ iter = 9900
# epoch 64, minibatch 156/156, validation error 20.072115 %
# training @ iter = 10000
# training @ iter = 10100
# epoch 65, minibatch 156/156, validation error 20.062099 %
#      epoch 65, minibatch 156/156, test error of best model 20.903446 %
# training @ iter = 10200
# epoch 66, minibatch 156/156, validation error 20.062099 %
# training @ iter = 10300
# training @ iter = 10400
# epoch 67, minibatch 156/156, validation error 20.052083 %
#      epoch 67, minibatch 156/156, test error of best model 20.853365 %
# training @ iter = 10500
# training @ iter = 10600
# epoch 68, minibatch 156/156, validation error 20.042067 %
#      epoch 68, minibatch 156/156, test error of best model 20.833333 %
# training @ iter = 10700
# epoch 69, minibatch 156/156, validation error 20.012019 %
#      epoch 69, minibatch 156/156, test error of best model 20.883413 %
# training @ iter = 10800
# training @ iter = 10900
# epoch 70, minibatch 156/156, validation error 20.022035 %
# training @ iter = 11000
# epoch 71, minibatch 156/156, validation error 19.991987 %
#      epoch 71, minibatch 156/156, test error of best model 20.873397 %
# training @ iter = 11100
# training @ iter = 11200
# epoch 72, minibatch 156/156, validation error 19.981971 %
#      epoch 72, minibatch 156/156, test error of best model 20.903446 %
# training @ iter = 11300
# epoch 73, minibatch 156/156, validation error 20.012019 %
# training @ iter = 11400
# training @ iter = 11500
# epoch 74, minibatch 156/156, validation error 20.012019 %
# training @ iter = 11600
# epoch 75, minibatch 156/156, validation error 20.012019 %
# training @ iter = 11700
# training @ iter = 11800
# epoch 76, minibatch 156/156, validation error 20.002003 %
# training @ iter = 11900
# training @ iter = 12000
# epoch 77, minibatch 156/156, validation error 19.991987 %
# training @ iter = 12100
# epoch 78, minibatch 156/156, validation error 20.002003 %
# training @ iter = 12200
# training @ iter = 12300
# epoch 79, minibatch 156/156, validation error 20.002003 %
# training @ iter = 12400
# epoch 80, minibatch 156/156, validation error 19.961939 %
#      epoch 80, minibatch 156/156, test error of best model 20.903446 %
# training @ iter = 12500
# training @ iter = 12600
# epoch 81, minibatch 156/156, validation error 19.981971 %
# training @ iter = 12700
# epoch 82, minibatch 156/156, validation error 19.971955 %
# training @ iter = 12800
# training @ iter = 12900
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-faefda638b75> in <module>()
#       1 import theano.tensor as T
#       2 from hw3 import MY_lenet
# ----> 3 MY_lenet(datasets, learning_rate=0.03, n_epochs=200, nkerns=[32, 64,128,256], batch_size=256, activation = T.nnet.relu)
#
# /home/ubuntu/e4040_hw3_cp2923/src/hw3.py in MY_lenet(datasets, learning_rate, n_epochs, nkerns, batch_size, activation)
#     532                 # compute zero-one loss on validation set
#     533                 validation_losses = [validate_model(i) for i
# --> 534                                      in range(n_valid_batches)]
#     535                 this_validation_loss = numpy.mean(validation_losses)
#     536                 print('epoch %i, minibatch %i/%i, validation error %f %%' %
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     864         try:
#     865             outputs =\
# --> 866                 self.fn() if output_subset is None else\
#     867                 self.fn(output_subset=output_subset)
#     868         except Exception:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Problem 4: Implement the convolutional neural network depicted in this problem

# %% [markdown]
# I used adam.py from https://gist.github.com/Newmu/acb738767acb4788bac3.
# I used adam for gradient and implement the required framework.

# %%
from hw3 import MY_CNN
img = MY_CNN(datasets, learning_rate=0.05, n_epochs=30, nkerns=[64, 128, 256], batch_size=256)
# Out:
# ... building the model
# ... training
# training @ iter = 0
# training @ iter = 100
# epoch 1, MSE = 0.006646
# training @ iter = 200
# training @ iter = 300
# epoch 2, MSE = 0.004942
# training @ iter = 400
# epoch 3, MSE = 0.004102
# training @ iter = 500
# training @ iter = 600
# epoch 4, MSE = 0.003568
# training @ iter = 700
# epoch 5, MSE = 0.003147
# training @ iter = 800
# training @ iter = 900
# epoch 6, MSE = 0.002778
# training @ iter = 1000
# epoch 7, MSE = 0.002506
# training @ iter = 1100
# training @ iter = 1200
# epoch 8, MSE = 0.002250
# training @ iter = 1300
# training @ iter = 1400
# epoch 9, MSE = 0.002002
# training @ iter = 1500
# epoch 10, MSE = 0.001801
# training @ iter = 1600
# training @ iter = 1700
# epoch 11, MSE = 0.001650
# training @ iter = 1800
# epoch 12, MSE = 0.001513
# training @ iter = 1900
# training @ iter = 2000
# epoch 13, MSE = 0.001396
# training @ iter = 2100
# epoch 14, MSE = 0.001285
# training @ iter = 2200
# training @ iter = 2300
# epoch 15, MSE = 0.001206
# training @ iter = 2400
# epoch 16, MSE = 0.001144
# training @ iter = 2500
# training @ iter = 2600
# epoch 17, MSE = 0.001082
# training @ iter = 2700
# training @ iter = 2800
# epoch 18, MSE = 0.001020
# training @ iter = 2900
# epoch 19, MSE = 0.000976
# training @ iter = 3000
# training @ iter = 3100
# epoch 20, MSE = 0.000915
# training @ iter = 3200
# epoch 21, MSE = 0.000881
# training @ iter = 3300
# training @ iter = 3400
# epoch 22, MSE = 0.000845
# training @ iter = 3500
# epoch 23, MSE = 0.000820
# training @ iter = 3600
# training @ iter = 3700
# epoch 24, MSE = 0.000780
# training @ iter = 3800
# epoch 25, MSE = 0.000763
# training @ iter = 3900
# training @ iter = 4000
# epoch 26, MSE = 0.000744
# training @ iter = 4100
# training @ iter = 4200
# epoch 27, MSE = 0.000706
# training @ iter = 4300
# epoch 28, MSE = 0.000695
# training @ iter = 4400
# training @ iter = 4500
# epoch 29, MSE = 0.000662
# training @ iter = 4600
# epoch 30, MSE = 0.000656
# The code for file hw3.pyc ran for 814.94m

# %%
#origion
# %matplotlib inline
axarr = plt.subplots(2,4)[1]
for i in range(4):
    plt.axes(axarr[0,i])
    plt.imshow(img[0][i].transpose(1,2,0))
    plt.axes(axarr[1,i])
    plt.imshow(img[0][4+i].transpose(1,2,0))

# %%
#dropped
# %matplotlib inline
axarr = plt.subplots(2,4)[1]
for i in range(4):
    plt.axes(axarr[0,i])
    plt.imshow(img[1][i].transpose(1,2,0))
    plt.axes(axarr[1,i])
    plt.imshow(img[1][4+i].transpose(1,2,0))

# %%
#recovered
# %matplotlib inline
axarr = plt.subplots(2,4)[1]
for i in range(4):
    plt.axes(axarr[0,i])
    plt.imshow(img[2][i].transpose(1,2,0))
    plt.axes(axarr[1,i])
    plt.imshow(img[2][4+i].transpose(1,2,0))
