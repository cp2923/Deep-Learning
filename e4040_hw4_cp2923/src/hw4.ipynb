# %% [markdown]
# ## ECBM E4040 Homework 4 - Programming Problem

# %%
import theano
import hw4a
#import hw4b

# %% [markdown]
# ### Problem a: Recurrent Neural Network
# #### Bullet 1: Experiment with RNNSLU

# %%
hw4a.test_rnnslu(win=7, emb_dimension=40, nepochs = 80)
# Out:
# verbose: True
# normal: True
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 40
# nepochs: 80
# nhidden: 200
# decay: True
# idx2word: False
# lr: 0.0970806646813
# folder: ../result
# layernormal: False
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.79 best test F1 65.74
# NEW BEST: epoch 1 valid F1 79.78 best test F1 76.83
# NEW BEST: epoch 2 valid F1 83.61 best test F1 81.2
# NEW BEST: epoch 3 valid F1 88.36 best test F1 84.91
# NEW BEST: epoch 4 valid F1 89.15 best test F1 85.49
# NEW BEST: epoch 5 valid F1 91.02 best test F1 87.38
# NEW BEST: epoch 6 valid F1 91.55 best test F1 88.78
# NEW BEST: epoch 7 valid F1 92.01 best test F1 89.92
# NEW BEST: epoch 8 valid F1 94.0 best test F1 91.07
# NEW BEST: epoch 9 valid F1 94.22 best test F1 91.28
# NEW BEST: epoch 10 valid F1 94.26 best test F1 91.59
# NEW BEST: epoch 11 valid F1 94.51 best test F1 92.16
# NEW BEST: epoch 12 valid F1 95.0 best test F1 92.28
# ...

# %%
hw4a.test_rnnslu(win=3, emb_dimension=40, nepochs = 80)
# Out:
# verbose: True
# normal: True
# win: 3
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 40
# nepochs: 80
# nhidden: 200
# decay: True
# idx2word: False
# lr: 0.0970806646813
# folder: ../result
# layernormal: False
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.14 best test F1 64.77
# NEW BEST: epoch 1 valid F1 79.24 best test F1 76.18
# NEW BEST: epoch 2 valid F1 82.22 best test F1 79.94
# NEW BEST: epoch 3 valid F1 86.18 best test F1 83.3
# NEW BEST: epoch 4 valid F1 88.8 best test F1 85.06
# NEW BEST: epoch 5 valid F1 89.73 best test F1 85.9
#
# NEW BEST: epoch 7 valid F1 91.29 best test F1 88.65
# NEW BEST: epoch 8 valid F1 92.55 best test F1 90.3
# NEW BEST: epoch 9 valid F1 93.42 best test F1 90.9
# NEW BEST: epoch 10 valid F1 93.75 best test F1 91.42
#
# NEW BEST: epoch 12 valid F1 94.79 best test F1 92.24
#
#
#
# NEW BEST: epoch 16 valid F1 95.13 best test F1 93.21
# ...

# %%
hw4a.test_rnnslu(win=7, emb_dimension=20, nepochs = 80)
# Out:
# verbose: True
# normal: True
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 20
# nepochs: 80
# nhidden: 200
# decay: True
# idx2word: False
# lr: 0.0970806646813
# folder: ../result
# layernormal: False
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.57 best test F1 65.57
# NEW BEST: epoch 1 valid F1 78.85 best test F1 75.85
# NEW BEST: epoch 2 valid F1 82.46 best test F1 79.91
# NEW BEST: epoch 3 valid F1 86.08 best test F1 83.99
# NEW BEST: epoch 4 valid F1 88.95 best test F1 85.34
# NEW BEST: epoch 5 valid F1 90.04 best test F1 86.36
# NEW BEST: epoch 6 valid F1 91.02 best test F1 88.76
# NEW BEST: epoch 7 valid F1 91.9 best test F1 89.93
# NEW BEST: epoch 8 valid F1 92.77 best test F1 90.37
# NEW BEST: epoch 9 valid F1 92.96 best test F1 90.92
# NEW BEST: epoch 10 valid F1 94.08 best test F1 91.91
# NEW BEST: epoch 11 valid F1 94.16 best test F1 92.2
# NEW BEST: epoch 12 valid F1 95.22 best test F1 93.27
#
#
# ...

# %%
hw4a.test_rnnslu(win=3, emb_dimension=20, nepochs = 80)
# Out:
# verbose: True
# normal: True
# win: 3
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 20
# nepochs: 80
# nhidden: 200
# decay: True
# idx2word: False
# lr: 0.0970806646813
# folder: ../result
# layernormal: False
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 67.87 best test F1 64.3
# NEW BEST: epoch 1 valid F1 78.55 best test F1 75.41
# NEW BEST: epoch 2 valid F1 82.07 best test F1 78.68
# NEW BEST: epoch 3 valid F1 85.62 best test F1 82.74
# NEW BEST: epoch 4 valid F1 87.64 best test F1 84.42
# NEW BEST: epoch 5 valid F1 89.91 best test F1 86.33
# NEW BEST: epoch 6 valid F1 90.17 best test F1 87.14
# NEW BEST: epoch 7 valid F1 91.52 best test F1 89.28
# NEW BEST: epoch 8 valid F1 92.54 best test F1 89.32
#
# NEW BEST: epoch 10 valid F1 93.16 best test F1 90.67
# NEW BEST: epoch 11 valid F1 93.81 best test F1 91.72
# NEW BEST: epoch 12 valid F1 94.48 best test F1 91.69
# NEW BEST: epoch 13 valid F1 94.73 best test F1 92.3
# ...

# %% [markdown]
# The RNN model with a context window of 7, and 40 word embeddings was the best one. Its F1 was 93.84 on the test data. The F1 on test data of four models are quite similarly. It might due to this learning task is not very hard and the hyperparameter is not that important.

# %% [markdown]
# #### Bullet 2: Experiment with RNNSLU without normalizing word embeddings

# %%
hw4a.test_rnnslu(win=7, emb_dimension=40, nepochs = 80, normal = False)
# Out:
# verbose: True
# normal: False
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 40
# nepochs: 80
# nhidden: 200
# decay: True
# idx2word: False
# lr: 0.0970806646813
# folder: ../result
# layernormal: False
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.38 best test F1 62.27
# NEW BEST: epoch 1 valid F1 79.64 best test F1 76.14
# NEW BEST: epoch 2 valid F1 84.51 best test F1 81.96
# NEW BEST: epoch 3 valid F1 87.94 best test F1 84.24
# NEW BEST: epoch 4 valid F1 89.89 best test F1 85.72
# NEW BEST: epoch 5 valid F1 91.24 best test F1 87.4
# NEW BEST: epoch 6 valid F1 92.39 best test F1 89.01
# NEW BEST: epoch 7 valid F1 93.2 best test F1 90.56
# NEW BEST: epoch 8 valid F1 94.0 best test F1 91.34
# NEW BEST: epoch 9 valid F1 94.45 best test F1 91.68
# NEW BEST: epoch 10 valid F1 94.76 best test F1 92.62
# NEW BEST: epoch 11 valid F1 95.09 best test F1 92.85
# NEW BEST: epoch 12 valid F1 95.67 best test F1 93.11
#
# ...

# %% [markdown]
# It is quite strange to me that the best test error without normalizing the word embeddings was actually than the corresponding test with normalizaing the embeddings. But this is only a small difference which might just be a coincidence.

# %% [markdown]
# #### Bullet 3: Implement RNN with two hidden layers

# %%
hw4a.test_rnnslu2(win=7, emb_dimension=40, nepochs = 80, normal = True)
# Out:
# verbose: True
# normal: True
# nhidden2: 100
# win: 7
# nhidden1: 200
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 40
# nepochs: 80
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 57.96 best test F1 54.47
# NEW BEST: epoch 1 valid F1 69.81 best test F1 67.33
# NEW BEST: epoch 2 valid F1 77.76 best test F1 74.89
# NEW BEST: epoch 3 valid F1 81.46 best test F1 78.83
# NEW BEST: epoch 4 valid F1 83.7 best test F1 80.53
# NEW BEST: epoch 5 valid F1 85.67 best test F1 83.2
# NEW BEST: epoch 6 valid F1 88.15 best test F1 84.18
# NEW BEST: epoch 7 valid F1 89.61 best test F1 86.18
# NEW BEST: epoch 8 valid F1 89.88 best test F1 86.93
#
# NEW BEST: epoch 10 valid F1 90.63 best test F1 88.02
# NEW BEST: epoch 11 valid F1 91.43 best test F1 88.55
# NEW BEST: epoch 12 valid F1 92.4 best test F1 89.77
# NEW BEST: epoch 13 valid F1 92.79 best test F1 89.96
#
# ...

# %% [markdown]
# I feel strange again since a second layer mlp's best test F1 was even lower than the single layer mlp. Though I don't have a proper explaination about this phenomenon, I generally believe it may due to lack of epochs.

# %% [markdown]
# #### Bullet 4: Experiment with layer normalization

# %%
hw4a.test_rnnslu(win=7, emb_dimension=40, nepochs = 80, layernormal = True)
# Out:
# verbose: True
# normal: True
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 40
# nepochs: 80
# nhidden: 200
# decay: True
# idx2word: False
# lr: 0.0970806646813
# folder: ../result
# layernormal: True
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 83.34 best test F1 80.1
# NEW BEST: epoch 1 valid F1 86.59 best test F1 83.78
# NEW BEST: epoch 2 valid F1 91.68 best test F1 88.78
# NEW BEST: epoch 3 valid F1 93.27 best test F1 89.93
# NEW BEST: epoch 4 valid F1 93.83 best test F1 90.28
# NEW BEST: epoch 5 valid F1 94.57 best test F1 91.9
#
# NEW BEST: epoch 7 valid F1 95.11 best test F1 92.83
# NEW BEST: epoch 8 valid F1 95.36 best test F1 93.22
# NEW BEST: epoch 9 valid F1 95.56 best test F1 92.95
# NEW BEST: epoch 10 valid F1 95.91 best test F1 93.07
# NEW BEST: epoch 11 valid F1 95.96 best test F1 93.58
# NEW BEST: epoch 12 valid F1 96.51 best test F1 93.58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
hw4a.test_rnnslu(win=3, emb_dimension=40, nepochs = 80, layernormal = True)
# Out:
# verbose: True
# normal: True
# win: 3
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 40
# nepochs: 80
# nhidden: 200
# decay: True
# idx2word: False
# lr: 0.0970806646813
# folder: ../result
# layernormal: True
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 83.84 best test F1 80.4
# NEW BEST: epoch 1 valid F1 87.35 best test F1 83.29
# NEW BEST: epoch 2 valid F1 91.62 best test F1 88.34
# NEW BEST: epoch 3 valid F1 92.74 best test F1 90.05
#
# NEW BEST: epoch 5 valid F1 93.89 best test F1 90.59
#
# NEW BEST: epoch 7 valid F1 94.89 best test F1 92.5
# NEW BEST: epoch 8 valid F1 95.61 best test F1 92.43
# NEW BEST: epoch 9 valid F1 95.68 best test F1 92.94
# NEW BEST: epoch 10 valid F1 96.18 best test F1 92.29
#
# NEW BEST: epoch 12 valid F1 96.48 best test F1 93.18
#
#
# NEW BEST: epoch 15 valid F1 96.58 best test F1 93.48
#
#
#
#
# NEW BEST: epoch 20 valid F1 96.71 best test F1 93.73
# ...

# %%
hw4a.test_rnnslu(win=7, emb_dimension=20, nepochs = 80, layernormal = True)
# Out:
# verbose: True
# normal: True
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 20
# nepochs: 80
# nhidden: 200
# decay: True
# idx2word: False
# lr: 0.0970806646813
# folder: ../result
# layernormal: True
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 81.97 best test F1 77.51
# NEW BEST: epoch 1 valid F1 87.64 best test F1 83.69
# NEW BEST: epoch 2 valid F1 89.98 best test F1 87.03
# NEW BEST: epoch 3 valid F1 91.58 best test F1 89.0
# NEW BEST: epoch 4 valid F1 92.63 best test F1 89.21
# NEW BEST: epoch 5 valid F1 93.95 best test F1 90.62
#
# NEW BEST: epoch 7 valid F1 95.24 best test F1 92.64
#
#
# NEW BEST: epoch 10 valid F1 95.7 best test F1 92.66
# NEW BEST: epoch 11 valid F1 95.93 best test F1 92.25
# NEW BEST: epoch 12 valid F1 96.27 best test F1 93.48
#
# NEW BEST: epoch 14 valid F1 96.33 best test F1 93.74
#
#
# NEW BEST: epoch 17 valid F1 96.65 best test F1 93.74
#
#
#
#
#
#
#
# ...

# %%
hw4a.test_rnnslu(win=3, emb_dimension=20, nepochs = 80, layernormal = True)
# Out:
# verbose: True
# normal: True
# win: 3
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 20
# nepochs: 80
# nhidden: 200
# decay: True
# idx2word: False
# lr: 0.0970806646813
# folder: ../result
# layernormal: True
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 82.04 best test F1 78.04
# NEW BEST: epoch 1 valid F1 87.39 best test F1 83.55
# NEW BEST: epoch 2 valid F1 90.16 best test F1 87.46
# NEW BEST: epoch 3 valid F1 91.22 best test F1 88.76
# NEW BEST: epoch 4 valid F1 91.39 best test F1 88.88
# NEW BEST: epoch 5 valid F1 93.45 best test F1 91.05
#
# NEW BEST: epoch 7 valid F1 94.69 best test F1 92.8
# NEW BEST: epoch 8 valid F1 94.88 best test F1 92.13
#
# NEW BEST: epoch 10 valid F1 95.65 best test F1 93.0
#
# NEW BEST: epoch 12 valid F1 96.18 best test F1 92.97
#
#
# NEW BEST: epoch 15 valid F1 96.38 best test F1 93.14
#
# NEW BEST: epoch 17 valid F1 96.49 best test F1 93.1
# ...

# %% [markdown]
# By add layer normalization, the first test F1 are all much better than those without layer normalization. However, the final result are just slightly better than the origin test.

# %% [markdown]
# #### Bullet 5: Observation on embedding pairs

# %%
model, idx = hw4a.test_rnnslu(nepochs=40,idx2word = True)
# Out:
# verbose: True
# normal: True
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 40
# nhidden: 200
# decay: True
# idx2word: True
# lr: 0.0970806646813
# folder: ../result
# layernormal: False
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.18 best test F1 66.22
# NEW BEST: epoch 1 valid F1 80.63 best test F1 77.98
# NEW BEST: epoch 2 valid F1 83.79 best test F1 80.66
# NEW BEST: epoch 3 valid F1 88.42 best test F1 84.92
# NEW BEST: epoch 4 valid F1 89.65 best test F1 85.97
# NEW BEST: epoch 5 valid F1 91.02 best test F1 86.87
# NEW BEST: epoch 6 valid F1 91.45 best test F1 88.81
# NEW BEST: epoch 7 valid F1 92.05 best test F1 89.89
# NEW BEST: epoch 8 valid F1 93.78 best test F1 90.69
# NEW BEST: epoch 9 valid F1 94.19 best test F1 91.27
# NEW BEST: epoch 10 valid F1 94.7 best test F1 91.64
# NEW BEST: epoch 11 valid F1 94.88 best test F1 92.23
# NEW BEST: epoch 12 valid F1 95.4 best test F1 92.73
# ...

# %%
hw4a.similarity(model, idx, 381, 382, 498, 499)
hw4a.similarity(model, idx, 81, 82, 83, 84)
# Out:
# The similarity between (plane - planes) and (ticket - tickets) is: -0.0140884132712
# The similarity between (burbank - business) and (but - buy) is: 0.210566875605

# %% [markdown]
# It is quite obvious that the first two pair of words are much similiar than second two pair of words.

# %% [markdown]
# ### Problem b: Learning Parity Function
# #### Bullet 1: Shallow MLP

# %%
import theano
import hw4b

# %%
hw4b.test_mlp_parity(n_bit=8, learning_rate = 0.1, L1_reg=0.00, L2_reg=0.0001, n_epochs=30000,
             batch_size=64, n_hidden=50, verbose=False, n_hiddenLayers = 1)
# Out:
# ... building the model
# ... training
# Optimization complete. Best validation score of 0.000000 % obtained at iteration 10245, with test performance 0.000000 %
# The code for file hw4b.py ran for 1.23m
# 0.0

# %%
hw4b.test_mlp_parity(n_bit=12, learning_rate=0.08, L1_reg=0.0001, L2_reg=0.0001, n_epochs=50000,
                     batch_size=16, n_hidden=12, n_hiddenLayers=1, verbose=False)
# Out:
# ... building the model
# ... training
# Optimization complete. Best validation score of 4.435484 % obtained at iteration 294872, with test performance 0.000000 %
# The code for file hw4b.py ran for 0.56m
# 0.0

# %% [markdown]
# #### Bullet 2: Deep MLP

# %%
hw4b.test_mlp_parity(n_bit=8, learning_rate=0.05, L1_reg=0.0001, L2_reg=0.0001, n_epochs=50000,
                     batch_size=64, n_hidden=100, n_hiddenLayers=2, verbose=False)
# Out:
# ... building the model
# ... training
# Optimization complete. Best validation score of 2.678571 % obtained at iteration 39885, with test performance 0.000000 %
# The code for file hw4b.py ran for 0.69m
# 0.0

# %%
hw4b.test_mlp_parity(n_bit=12, learning_rate=0.05, L1_reg=0.0001, L2_reg=0.00001, n_epochs=50000,
                     batch_size=32, n_hidden=50, n_hiddenLayers=4, verbose=False)
# Out:
# ... building the model
# ... training
# Optimization complete. Best validation score of 1.250000 % obtained at iteration 11439, with test performance 0.000000 %
# The code for file hw4b.pyc ran for 0.12m
# 0.0

# %% [markdown]
# #### Bullet 3: RNN

# %%
hw4b.test_rnn_parity(n_bit=8,verbose = False)
# Out:
# ... loading the dataset
# ... building the model
# ... training
# ('BEST RESULT: epoch', 9, 'valid F1', 1.0, 'best test F1', 1.0, 'with the model', '../result')

# %%
hw4b.test_rnn_parity(n_bit=12,verbose = False)
# Out:
# ... loading the dataset
# ... building the model
# ... training
# ('BEST RESULT: epoch', 12, 'valid F1', 1.0, 'best test F1', 1.0, 'with the model', '../result')

# %% [markdown]
# #### Bullet 4: LSTM

# %%
hw4b.test_lstm_parity(n_bit=8, nhidden = 1, verbose = False)
# Out:
# ... loading the dataset
# ... building the model
# ... training
# ('BEST RESULT: epoch', 3, 'valid F1', 1.0, 'best test F1', 1.0, 'with the model', '../result')

# %%
hw4b.test_lstm_parity(n_bit=12, nhidden = 1, verbose = False)
# Out:
# ... loading the dataset
# ... building the model
# ... training
# ('BEST RESULT: epoch', 4, 'valid F1', 1.0, 'best test F1', 1.0, 'with the model', '../result')
